# %%
import pandas as pd

# %%
data = pd.read_csv("/Salary_dataset.csv")
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
x= data['YearsExperience']

# %%
y= data['Salary']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,4))
plt.scatter(x,y,s=150 , color  ='green')
plt.grid()
plt.xlabel('YearsExperience ----->')
plt.ylabel('Salary  ---->')
plt.title('YearsExperience vs Salary')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
x
# Out:
# 0      1.2
# 1      1.4
# 2      1.6
# 3      2.1
# 4      2.3
# 5      3.0
# 6      3.1
# 7      3.3
# 8      3.3
# 9      3.8
# 10     4.0
# 11     4.1
# 12     4.1
# 13     4.2
# 14     4.6
# 15     5.0
# 16     5.2
# 17     5.4
# 18     6.0
# 19     6.1
# 20     6.9
# 21     7.2
# 22     8.0
# 23     8.3
# 24     8.8
# 25     9.1
# 26     9.6
# 27     9.7
# 28    10.4
# 29    10.6
# Name: YearsExperience, dtype: float64

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x= data[['YearsExperience']]

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([9449.96232146])

# %%
model.intercept_
# Out:
# np.float64(24848.203966523193)

# %%
model.predict([[5]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([72098.0155738])

# %%
y_pred = model.predict(x)
y_pred
# Out:
# array([ 36188.15875227,  38078.15121656,  39968.14368085,  44693.12484158,
#         46583.11730587,  53198.09093089,  54143.08716303,  56033.07962732,
#         56033.07962732,  60758.06078805,  62648.05325234,  63593.04948449,
#         63593.04948449,  64538.04571663,  68318.03064522,  72098.0155738 ,
#         73988.00803809,  75878.00050238,  81547.97789525,  82492.9741274 ,
#         90052.94398456,  92887.932681  , 100447.90253816, 103282.8912346 ,
#        108007.87239533, 110842.86109176, 115567.84225249, 116512.83848464,
#        123127.81210966, 125017.80457395])

# %%
data['Model_Prediction']=y_pred

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary  Model_Prediction
# 0            0              1.2   39344.0      36188.158752
# 1            1              1.4   46206.0      38078.151217
# 2            2              1.6   37732.0      39968.143681
# 3            3              2.1   43526.0      44693.124842
# 4            4              2.3   39892.0      46583.117306
# 5            5              3.0   56643.0      53198.090931
# 6            6              3.1   60151.0      54143.087163
# 7            7              3.3   54446.0      56033.079627
# 8            8              3.3   64446.0      56033.079627
# 9            9              3.8   57190.0      60758.060788
# 10          10              4.0   63219.0      62648.053252
# 11          11              4.1   55795.0      63593.049484
# 12          12              4.1   56958.0      63593.049484
# 13          13              4.2   57082.0      64538.045717
# 14          14              4.6   61112.0      68318.030645
# ...

# %%
import numpy as np

# %%
data['Model_Prediction']=np.round(y_pred,2)

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary  Model_Prediction
# 0            0              1.2   39344.0          36188.16
# 1            1              1.4   46206.0          38078.15
# 2            2              1.6   37732.0          39968.14
# 3            3              2.1   43526.0          44693.12
# 4            4              2.3   39892.0          46583.12
# 5            5              3.0   56643.0          53198.09
# 6            6              3.1   60151.0          54143.09
# 7            7              3.3   54446.0          56033.08
# 8            8              3.3   64446.0          56033.08
# 9            9              3.8   57190.0          60758.06
# 10          10              4.0   63219.0          62648.05
# 11          11              4.1   55795.0          63593.05
# 12          12              4.1   56958.0          63593.05
# 13          13              4.2   57082.0          64538.05
# 14          14              4.6   61112.0          68318.03
# ...

# %%
plt.figure(figsize=(12,4))
plt.scatter(x,y,s=160,color='green',label='Actual Data points') # area vs actual price
plt.scatter(x,y_pred,s=160,color='red',marker='x',label='Model Prediction') # area vs predicted price
plt.plot(x,y_pred, color='red',linestyle='--',label='Model Line') # model line
plt.xlabel('YearsExperience ----->')
plt.ylabel('Salary  ---->')
plt.title('YearsExperience vs Salary')
plt.grid()
plt.legend()
plt.show()

# %%
df_outlier=pd.DataFrame(data)
df_outlier
# Out:
#     Unnamed: 0  YearsExperience    Salary  Model_Prediction
# 0            0              1.2   39344.0          36188.16
# 1            1              1.4   46206.0          38078.15
# 2            2              1.6   37732.0          39968.14
# 3            3              2.1   43526.0          44693.12
# 4            4              2.3   39892.0          46583.12
# 5            5              3.0   56643.0          53198.09
# 6            6              3.1   60151.0          54143.09
# 7            7              3.3   54446.0          56033.08
# 8            8              3.3   64446.0          56033.08
# 9            9              3.8   57190.0          60758.06
# 10          10              4.0   63219.0          62648.05
# 11          11              4.1   55795.0          63593.05
# 12          12              4.1   56958.0          63593.05
# 13          13              4.2   57082.0          64538.05
# 14          14              4.6   61112.0          68318.03
# ...

# %%
x=df_outlier[['YearsExperience']]
y=df_outlier['Salary']

# %%
plt.figure(figsize=(12,4))
plt.scatter(x,y,s=160,color='green')
plt.xlabel('YearsExperience ----->')
plt.ylabel('Salary ---->')
plt.title('YearsExperience')
plt.grid()

# %%
model_linear=LinearRegression()

# %%
x
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
data['Error']= data['Salary']- data['Model_Prediction']

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary  Model_Prediction     Error
# 0            0              1.2   39344.0          36188.16   3155.84
# 1            1              1.4   46206.0          38078.15   8127.85
# 2            2              1.6   37732.0          39968.14  -2236.14
# 3            3              2.1   43526.0          44693.12  -1167.12
# 4            4              2.3   39892.0          46583.12  -6691.12
# 5            5              3.0   56643.0          53198.09   3444.91
# 6            6              3.1   60151.0          54143.09   6007.91
# 7            7              3.3   54446.0          56033.08  -1587.08
# 8            8              3.3   64446.0          56033.08   8412.92
# 9            9              3.8   57190.0          60758.06  -3568.06
# 10          10              4.0   63219.0          62648.05    570.95
# 11          11              4.1   55795.0          63593.05  -7798.05
# ...

# %%
data['Error'].mean()
# Out:
# np.float64(0.0006666666670450164)

# %%
abs(5)
# Out:
# 5

# %%
data['abs error']= abs(data['Error'])

# %%
data['abs error'].mean()
# Out:
# np.float64(4644.202000000002)

# %%
data['sq error']=data['Error']**2

# %%
data['sq error'].mean()
# Out:
# np.float64(31270961.046540007)

# %%
data['sq error'].mean()**0.5
# Out:
# np.float64(5592.044442468247)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error

# %%
mean_squared_error(y,y_pred)
# Out:
# 31270951.722280953

# %%
mean_squared_error(y,y_pred)**0.5
# Out:
# 5592.04360876066

# %%
root_mean_squared_error(y,y_pred)
# Out:
# 5592.04360876066

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y,y_pred)
# Out:
# 0.9569566641435086
